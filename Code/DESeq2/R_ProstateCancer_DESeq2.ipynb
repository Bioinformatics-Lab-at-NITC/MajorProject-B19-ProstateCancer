# %% [markdown]
# <a href="https://colab.research.google.com/github/SanandhKumar02/Main_Project/blob/main/R_ProstateCancer_DESeq2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if (!requireNamespace("BiocManager", quietly=TRUE))
    install.packages("BiocManager")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
R.version.string
# Out:
# [1] "R version 4.2.0 (2022-04-22)"

# %%
BiocManager::install("TCGAbiolinks")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# '?repositories' for details
#
# replacement repositories:
#     CRAN: https://cran.rstudio.com
#
#
# Bioconductor version 3.15 (BiocManager 1.30.18), R 4.2.0 (2022-04-22)
#
# Installing package(s) 'BiocVersion', 'TCGAbiolinks'
#
# also installing the dependencies ‘plogr’, ‘png’, ‘Biostrings’, ‘bitops’, ‘RSQLite’, ‘KEGGREST’, ‘filelock’, ‘RCurl’, ‘GenomeInfoDbData’, ‘zlibbioc’, ‘matrixStats’, ‘AnnotationDbi’, ‘BiocFileCache’, ‘BiocGenerics’, ‘GenomeInfoDb’, ‘XVector’, ‘Rcpp’, ‘R.oo’, ‘R.methodsS3’, ‘MatrixGenerics’, ‘Biobase’, ‘DelayedArray’, ‘downloader’, ‘biomaRt’, ‘GenomicRanges’, ‘XML’, ‘plyr’, ‘IRanges’, ‘S4Vectors’, ‘R.utils’, ‘SummarizedExperiment’, ‘TCGAbiolinksGUI.data’
#
#
# Old packages: 'broom', 'dbplyr', 'pkgload', 'rlang', 'nlme'

# %%
library(TCGAbiolinks)

# %%
library(SummarizedExperiment)
# Out:
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians

# %%
library(ggplot2)

# %%
BiocManager::install("DESeq2")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# '?repositories' for details
#
# replacement repositories:
#     CRAN: https://cran.rstudio.com
#
#
# Bioconductor version 3.15 (BiocManager 1.30.18), R 4.2.0 (2022-04-22)
#
# Installing package(s) 'DESeq2'
#
# also installing the dependencies ‘formatR’, ‘lambda.r’, ‘futile.options’, ‘xtable’, ‘futile.logger’, ‘snow’, ‘BH’, ‘annotate’, ‘BiocParallel’, ‘genefilter’, ‘locfit’, ‘geneplotter’, ‘RcppArmadillo’
#
#
# Old packages: 'broom', 'dbplyr', 'pkgload', 'rlang', 'nlme'

# %%
library(DESeq2)

# %% [markdown]
# # **Function to get Up-regulated and Down-regulated Genes**

# %%
get_upregulated <- function(df){
    key <- intersect(rownames(df)[which(df$log2FoldChange>=1)],
              rownames(df)[which(df$pvalue<=0.05)])
    
    results <- as.data.frame((df)[which(rownames(df) %in% key),])
    return(results)
  }

# %%
get_downregulated <- function(df){
  key <- intersect(rownames(df)[which(df$log2FoldChange<=-1)],
            rownames(df)[which(df$pvalue<=0.05)])
  
  results <- as.data.frame((df)[which(rownames(df) %in% key),])
  return(results)
}

# %% [markdown]
# # ***miRNA Differential Analysis***

# %% [markdown]
# ## Downloading and Preparing Data

# %%
mirna_query <- GDCquery(project = "TCGA-PRAD",
                        data.category = "Transcriptome Profiling",
                        data.type = "miRNA Expression Quantification",
                        experimental.strategy = "miRNA-Seq")
# Out:
# --------------------------------------
#
# o GDCquery: Searching in GDC database
#
# --------------------------------------
#
# Genome of reference: hg38
#
# --------------------------------------------
#
# oo Accessing GDC. This might take a while...
#
# --------------------------------------------
#
# ooo Project: TCGA-PRAD
#
# --------------------
#
# oo Filtering results
#
# --------------------
#
# ooo By experimental.strategy
#
# ooo By data.type
#
# ----------------
#
# oo Checking data
#
# ----------------
#
# ooo Checking if there are duplicated cases
#
# ooo Checking if there are results for the query
#
# -------------------
#
# o Preparing output
#
# -------------------

# %%
GDCdownload(mirna_query, method = "api", files.per.chunk = 100,
            directory = "/Desktop/Data")
# Out:
# Downloading data for project TCGA-PRAD
#
# GDCdownload will download 551 files. A total of 27.635813 MB
#
# Downloading chunk 1 of 6 (100 files, size = 5.016283 MB) as Tue_Jul__5_08_29_02_2022_0.tar.gz
# Downloading: 800 kB
# Downloading chunk 2 of 6 (100 files, size = 5.014826 MB) as Tue_Jul__5_08_29_02_2022_1.tar.gz
# Downloading: 790 kB
# Downloading chunk 3 of 6 (100 files, size = 5.016307 MB) as Tue_Jul__5_08_29_02_2022_2.tar.gz
# Downloading: 800 kB
# Downloading chunk 4 of 6 (100 files, size = 5.015151 MB) as Tue_Jul__5_08_29_02_2022_3.tar.gz
# Downloading: 790 kB
# Downloading chunk 5 of 6 (100 files, size = 5.015926 MB) as Tue_Jul__5_08_29_02_2022_4.tar.gz
# Downloading: 800 kB
# Downloading chunk 6 of 6 (51 files, size = 2.55732 MB) as Tue_Jul__5_08_29_02_2022_5.tar.gz
# Downloading: 400 kB

# %%
miR_df <- GDCprepare(mirna_query, directory = "/Desktop/Data")
# Out:
#   |======================================================================| 100%

# %%
## remove columns we dont need, keep counts
rownames(miR_df) <- miR_df$miRNA_ID
miR_df <- miR_df[,-1]
number_cols <- ncol(miR_df)
subset <- seq(from = 1, to = number_cols, by = 3)
miR_df <- miR_df[, subset]

# %%
## Strip read_count, just want the 'cases' ID
colnames(miR_df) <- gsub(".*_","",colnames(miR_df))
nrow(miR_df)
ncol(miR_df)
head(miR_df)
# Out:
# [1] 1881
# [1] 551
#              TCGA-EJ-7321-01A-31R-2262-13 TCGA-J4-A83M-01A-11R-A358-13
# hsa-let-7a-1 51384                        37734
# hsa-let-7a-2 51537                        37846
# hsa-let-7a-3 51277                        37554
# hsa-let-7b   35001                        28807
# hsa-let-7c   15057                        18857
# hsa-let-7d    1095                         1511
#              TCGA-EJ-5501-01A-01R-1579-13 TCGA-V1-A9OY-01A-11R-A41R-13
# hsa-let-7a-1 32491                        43522
# hsa-let-7a-2 32453                        43443
# hsa-let-7a-3 32658                        43446
# hsa-let-7b   31775                        27308
# hsa-let-7c   21198                        23882
# hsa-let-7d     602                         1008
#              TCGA-EJ-5497-01A-02R-1579-13 TCGA-KK-A6E3-01A-21R-A30I-13
# hsa-let-7a-1 84251                        23004
# hsa-let-7a-2 84336                        23173
# hsa-let-7a-3 84391                        23213
# hsa-let-7b   86219                        21941
# hsa-let-7c   47062                        36790
# hsa-let-7d    1654                          866
#              TCGA-HC-A6AS-01A-11R-A30I-13 TCGA-HC-8260-11A-01R-2262-13
# hsa-let-7a-1 29078                        25262
# hsa-let-7a-2 29154                        25285
# hsa-let-7a-3 28906                        25584
# hsa-let-7b   23735                        26412
# hsa-let-7c   21241                        23683
# hsa-let-7d     883                          805
#              TCGA-EJ-A8FO-11A-11R-A36B-13 TCGA-G9-6377-01A-11R-1964-13 ⋯
# hsa-let-7a-1  98606                       85102                        ⋯
# hsa-let-7a-2 100143                       85016                        ⋯
# hsa-let-7a-3  99437                       84939                        ⋯
# hsa-let-7b    98270                       43293                        ⋯
# hsa-let-7c    95837                       41608                        ⋯
# hsa-let-7d     1963                        1412                        ⋯
#              TCGA-H9-A6BX-01A-31R-A310-13 TCGA-2A-A8VO-01A-11R-A37H-13
# hsa-let-7a-1 75660                        22796
# hsa-let-7a-2 75424                        22665
# hsa-let-7a-3 76109                        22841
# hsa-let-7b   53446                        16914
# hsa-let-7c   51912                        19811
# hsa-let-7d    2214                          902
#              TCGA-G9-7519-01A-11R-2262-13 TCGA-HC-8260-01A-11R-2262-13
# hsa-let-7a-1 33406                        31259
# hsa-let-7a-2 33020                        31219
# hsa-let-7a-3 33212                        31711
# hsa-let-7b   36323                        29629
# hsa-let-7c   32768                        22696
# hsa-let-7d     761                          837
#              TCGA-HC-A6AP-01A-11R-A30I-13 TCGA-EJ-A8FO-01A-21R-A36B-13
# hsa-let-7a-1 34031                        47400
# hsa-let-7a-2 33921                        47397
# hsa-let-7a-3 34118                        47301
# hsa-let-7b   32603                        46076
# hsa-let-7c   28238                        28752
# hsa-let-7d     956                         1216
#              TCGA-YL-A8SQ-01B-11R-A37H-13 TCGA-J4-A83J-11A-11R-A36B-13
# hsa-let-7a-1 28772                        62357
# hsa-let-7a-2 28290                        62452
# hsa-let-7a-3 28696                        62960
# hsa-let-7b   20158                        57235
# hsa-let-7c   23028                        62909
# hsa-let-7d     610                         2103
#              TCGA-M7-A723-01A-12R-A32J-13 TCGA-G9-6370-01A-11R-1788-13
# hsa-let-7a-1 40116                        22182
# hsa-let-7a-2 39838                        22410
# hsa-let-7a-3 39901                        22063
# hsa-let-7b   40825                        10417
# hsa-let-7c   23682                        22380
# hsa-let-7d    1287                          643

# %%
## Match to metadata
miR_meta <- mirna_query[[1]][[1]]

# %%
miR_meta <- miR_meta[,c("cases", "sample_type")]
nrow(miR_meta)
ncol(miR_meta)
# Out:
# [1] 551
# [1] 2

# %%
miR_meta$sample_type <- as.character(miR_meta$sample_type)
table(miR_meta$sample_type)
# Out:
#          Metastatic       Primary Tumor Solid Tissue Normal
#                   1                 498                  52

# %%
metastatic_key <- miR_meta[which(miR_meta$sample_type == "Metastatic"),]
miR_meta <- miR_meta[!miR_meta[,2] == metastatic_key[,2],]
miR_df <- miR_df[, -grep(paste0(metastatic_key[,1]), colnames(miR_df))]

# %%
head(miR_df)
nrow(miR_df)
ncol(miR_df)
# Out:
#              TCGA-EJ-7321-01A-31R-2262-13 TCGA-J4-A83M-01A-11R-A358-13
# hsa-let-7a-1 51384                        37734
# hsa-let-7a-2 51537                        37846
# hsa-let-7a-3 51277                        37554
# hsa-let-7b   35001                        28807
# hsa-let-7c   15057                        18857
# hsa-let-7d    1095                         1511
#              TCGA-EJ-5501-01A-01R-1579-13 TCGA-V1-A9OY-01A-11R-A41R-13
# hsa-let-7a-1 32491                        43522
# hsa-let-7a-2 32453                        43443
# hsa-let-7a-3 32658                        43446
# hsa-let-7b   31775                        27308
# hsa-let-7c   21198                        23882
# hsa-let-7d     602                         1008
#              TCGA-EJ-5497-01A-02R-1579-13 TCGA-KK-A6E3-01A-21R-A30I-13
# hsa-let-7a-1 84251                        23004
# hsa-let-7a-2 84336                        23173
# hsa-let-7a-3 84391                        23213
# hsa-let-7b   86219                        21941
# hsa-let-7c   47062                        36790
# hsa-let-7d    1654                          866
#              TCGA-HC-A6AS-01A-11R-A30I-13 TCGA-HC-8260-11A-01R-2262-13
# hsa-let-7a-1 29078                        25262
# hsa-let-7a-2 29154                        25285
# hsa-let-7a-3 28906                        25584
# hsa-let-7b   23735                        26412
# hsa-let-7c   21241                        23683
# hsa-let-7d     883                          805
#              TCGA-EJ-A8FO-11A-11R-A36B-13 TCGA-G9-6377-01A-11R-1964-13 ⋯
# hsa-let-7a-1  98606                       85102                        ⋯
# hsa-let-7a-2 100143                       85016                        ⋯
# hsa-let-7a-3  99437                       84939                        ⋯
# hsa-let-7b    98270                       43293                        ⋯
# hsa-let-7c    95837                       41608                        ⋯
# hsa-let-7d     1963                        1412                        ⋯
#              TCGA-H9-A6BX-01A-31R-A310-13 TCGA-2A-A8VO-01A-11R-A37H-13
# hsa-let-7a-1 75660                        22796
# hsa-let-7a-2 75424                        22665
# hsa-let-7a-3 76109                        22841
# hsa-let-7b   53446                        16914
# hsa-let-7c   51912                        19811
# hsa-let-7d    2214                          902
#              TCGA-G9-7519-01A-11R-2262-13 TCGA-HC-8260-01A-11R-2262-13
# hsa-let-7a-1 33406                        31259
# hsa-let-7a-2 33020                        31219
# hsa-let-7a-3 33212                        31711
# hsa-let-7b   36323                        29629
# hsa-let-7c   32768                        22696
# hsa-let-7d     761                          837
#              TCGA-HC-A6AP-01A-11R-A30I-13 TCGA-EJ-A8FO-01A-21R-A36B-13
# hsa-let-7a-1 34031                        47400
# hsa-let-7a-2 33921                        47397
# hsa-let-7a-3 34118                        47301
# hsa-let-7b   32603                        46076
# hsa-let-7c   28238                        28752
# hsa-let-7d     956                         1216
#              TCGA-YL-A8SQ-01B-11R-A37H-13 TCGA-J4-A83J-11A-11R-A36B-13
# hsa-let-7a-1 28772                        62357
# hsa-let-7a-2 28290                        62452
# hsa-let-7a-3 28696                        62960
# hsa-let-7b   20158                        57235
# hsa-let-7c   23028                        62909
# hsa-let-7d     610                         2103
#              TCGA-M7-A723-01A-12R-A32J-13 TCGA-G9-6370-01A-11R-1788-13
# hsa-let-7a-1 40116                        22182
# hsa-let-7a-2 39838                        22410
# hsa-let-7a-3 39901                        22063
# hsa-let-7b   40825                        10417
# hsa-let-7c   23682                        22380
# hsa-let-7d    1287                          643
# [1] 1881
# [1] 550

# %%
head(miR_meta)
nrow(miR_meta)
ncol(miR_meta)
# Out:
#   cases                        sample_type
# 1 TCGA-EJ-7321-01A-31R-2262-13 Primary Tumor
# 2 TCGA-J4-A83M-01A-11R-A358-13 Primary Tumor
# 3 TCGA-EJ-5501-01A-01R-1579-13 Primary Tumor
# 4 TCGA-V1-A9OY-01A-11R-A41R-13 Primary Tumor
# 5 TCGA-EJ-5497-01A-02R-1579-13 Primary Tumor
# 6 TCGA-KK-A6E3-01A-21R-A30I-13 Primary Tumor
# [1] 550
# [1] 2

# %%
## Rename conditions
miR_meta$sample_type <- gsub("Primary solid Tumor", "Tumor", miR_meta$sample_type)
miR_meta$sample_type <- gsub("Solid Tissue Normal", "Normal", miR_meta$sample_type)
miR_meta$sample_type <- as.factor(miR_meta$sample_type)
levels(miR_meta$sample_type)
colnames(miR_meta) <- c("cases", "Condition")
# Out:
# [1] "Normal"        "Primary Tumor"

# %%
write.table(miR_meta, "/Desktop/miR_meta.txt", quote = F, sep = "\t")

# %%
nrow(miR_df)
ncol(miR_df)
nrow(miR_meta)
ncol(miR_meta)
# Out:
# [1] 1881
# [1] 550
# [1] 550
# [1] 2

# %%
## tidy vars
rm(mirna_query)
rm(subset)
rm(number_cols)
rm(metastatic_key)

# %%
miR_dds <- DESeqDataSetFromMatrix(miR_df, colData = miR_meta, design = ~ Condition)
miR_dds$Condition <- relevel(miR_dds$Condition, ref = "Normal")
miR_dds <- DESeq(miR_dds)
resultsNames(miR_dds)
# Out:
#   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
#
# estimating size factors
#
#   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
#   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
#
# final dispersion estimates
#
#   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
#
# fitting model and testing
#
#   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
#
# -- replacing outliers and refitting for 59 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
#
# estimating dispersions
#
#   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
#
# fitting model and testing
#
#   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
# [1] "Intercept"                         "Condition_Primary.Tumor_vs_Normal"

# %%
## DESeq2 results
miR_res <- results(miR_dds, alpha = 0.05, name = "Condition_Primary.Tumor_vs_Normal")
summary(miR_res)
miR_res_df <- as.data.frame(miR_res)
# Out:
# out of 1513 with nonzero total read count
# adjusted p-value < 0.05
# LFC > 0 (up)       : 169, 11%
# LFC < 0 (down)     : 201, 13%
# outliers [1]       : 0, 0%
# low counts [2]     : 724, 48%
# (mean count < 0)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results

# %%
head(miR_res_df)
# Out:
#              baseMean  log2FoldChange lfcSE      stat      pvalue
# hsa-let-7a-1 39952.468  0.4454602     0.07895393  5.642027 1.680597e-08
# hsa-let-7a-2 39771.570  0.4404088     0.07889197  5.582429 2.371818e-08
# hsa-let-7a-3 39912.736  0.4397812     0.07877872  5.582487 2.371036e-08
# hsa-let-7b   34320.284 -0.1122421     0.08113033 -1.383479 1.665181e-01
# hsa-let-7c   26847.715 -0.2942461     0.09361531 -3.143140 1.671457e-03
# hsa-let-7d    1142.685  0.2468781     0.05357941  4.607704 4.071393e-06
#              padj
# hsa-let-7a-1 8.554782e-08
# hsa-let-7a-2 1.176959e-07
# hsa-let-7a-3 1.176959e-07
# hsa-let-7b   2.807325e-01
# hsa-let-7c   4.410634e-03
# hsa-let-7d   1.501088e-05

# %%
miR_upreg <- get_upregulated(miR_res)
miR_downreg <- get_downregulated(miR_res)

# %%
miR_upreg$miRNA_id <- rownames(miR_upreg)
miR_downreg$miRNA_id <- rownames(miR_downreg)

# %%
head(miR_upreg)
# Out:
#               baseMean   log2FoldChange lfcSE     stat     pvalue
# hsa-mir-106a  381.201642 1.363919       0.1413888 9.646580 5.082250e-22
# hsa-mir-122     1.300316 2.725508       0.7441354 3.662651 2.496189e-04
# hsa-mir-1255a   2.930956 1.128449       0.2421865 4.659420 3.171012e-06
# hsa-mir-1269a 116.446662 3.532623       0.5066740 6.972182 3.120628e-12
# hsa-mir-1269b   6.852310 3.284002       0.8339888 3.937706 8.226441e-05
# hsa-mir-1275    2.016900 1.523149       0.3502033 4.349328 1.365551e-05
#               padj         miRNA_id
# hsa-mir-106a  6.913612e-21 hsa-mir-106a
# hsa-mir-122   7.574974e-04 hsa-mir-122
# hsa-mir-1255a 1.185748e-05 hsa-mir-1255a
# hsa-mir-1269a 2.390462e-11 hsa-mir-1269a
# hsa-mir-1269b 2.606691e-04 hsa-mir-1269b
# hsa-mir-1275  4.704304e-05 hsa-mir-1275

# %%
miR_counts <- counts(miR_dds, normalized = T)
write.table(miR_counts, "/Desktop/miR_norm.counts.txt", quote = F, sep = "\t")

# %%
write.table(miR_upreg, "/Desktop/miR_upreg.txt", quote = F, sep = "\t")
write.table(miR_downreg, "/Desktop/miR_downreg.txt", quote = F, sep = "\t")

# %%
miR_res_df$miRNA_id <- rownames(miR_res_df)
head(miR_res_df)
# Out:
#              baseMean  log2FoldChange lfcSE      stat      pvalue
# hsa-let-7a-1 39952.468  0.4454602     0.07895393  5.642027 1.680597e-08
# hsa-let-7a-2 39771.570  0.4404088     0.07889197  5.582429 2.371818e-08
# hsa-let-7a-3 39912.736  0.4397812     0.07877872  5.582487 2.371036e-08
# hsa-let-7b   34320.284 -0.1122421     0.08113033 -1.383479 1.665181e-01
# hsa-let-7c   26847.715 -0.2942461     0.09361531 -3.143140 1.671457e-03
# hsa-let-7d    1142.685  0.2468781     0.05357941  4.607704 4.071393e-06
#              padj         miRNA_id
# hsa-let-7a-1 8.554782e-08 hsa-let-7a-1
# hsa-let-7a-2 1.176959e-07 hsa-let-7a-2
# hsa-let-7a-3 1.176959e-07 hsa-let-7a-3
# hsa-let-7b   2.807325e-01 hsa-let-7b
# hsa-let-7c   4.410634e-03 hsa-let-7c
# hsa-let-7d   1.501088e-05 hsa-let-7d

# %%
BiocManager::install("EnhancedVolcano")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# '?repositories' for details
#
# replacement repositories:
#     CRAN: https://cran.rstudio.com
#
#
# Bioconductor version 3.15 (BiocManager 1.30.18), R 4.2.0 (2022-04-22)
#
# Installing package(s) 'EnhancedVolcano'
#
# also installing the dependency ‘ggrepel’
#
#
# Old packages: 'broom', 'dbplyr', 'pkgload', 'rlang', 'nlme'

# %%
library("EnhancedVolcano")
# Out:
# Loading required package: ggrepel

# %%
EnhancedVolcano(miR_res_df, x="log2FoldChange", y="padj", lab = miR_res_df$miRNA_id)
# Out:
# plot without title

# %%
EnhancedVolcano(miR_res_df, x="log2FoldChange", y="padj", lab = miR_res_df$miRNA_id, pCutoff = 0.05, FCcutoff = 2)
# Out:
# plot without title

# %%
selectedDownRegGene = c("hsa-mir-888",
"hsa-mir-873",
"hsa-mir-760",
"hsa-mir-551b",
"hsa-mir-541",
"hsa-mir-488",
"hsa-mir-486",
"hsa-mir-381",
"hsa-mir-378",
"hsa-mir-3622a",
"hsa-mir-326",
"hsa-mir-143",
"hsa-mir-187",
"hsa-mir-205")

# %%
EnhancedVolcano(miR_res_df, x="log2FoldChange", y="padj", lab = miR_res_df$miRNA_id, pCutoff = 0.05, FCcutoff = 2, selectLab = selectedDownRegGene)
# Out:
# plot without title

# %%
selectedUpRegGene = c("hsa-mir-137",
"hsa-mir-141",
"hsa-mir-148a",
"hsa-mir-182",
"hsa-mir-19a",
"hsa-mir-19b",
"hsa-mir-20a",
"hsa-mir-3170",
"hsa-mir-3614",
"hsa-mir-375",
"hsa-mir-425",
"hsa-mir-449a",
"hsa-mir-449b",
"hsa-mir-615",
"hsa-mir-618",
"hsa-mir-708",
"hsa-mir-9",
"hsa-mir-93")

# %%
EnhancedVolcano(miR_res_df, x="log2FoldChange", y="padj", lab = miR_res_df$miRNA_id, pCutoff = 0.05, FCcutoff = 2, selectLab = selectedUpRegGene)
# Out:
# plot without title

# %%
selectedGene = c("hsa-mir-888",
"hsa-mir-873",
"hsa-mir-760",
"hsa-mir-551b",
"hsa-mir-541",
"hsa-mir-488",
"hsa-mir-486",
"hsa-mir-381",
"hsa-mir-378",
"hsa-mir-3622a",
"hsa-mir-326",
"hsa-mir-143",
"hsa-mir-187",
"hsa-mir-205",
"hsa-mir-137",
"hsa-mir-141",
"hsa-mir-148a",
"hsa-mir-182",
"hsa-mir-19a",
"hsa-mir-19b",
"hsa-mir-20a",
"hsa-mir-3170",
"hsa-mir-3614",
"hsa-mir-375",
"hsa-mir-425",
"hsa-mir-449a",
"hsa-mir-449b",
"hsa-mir-615",
"hsa-mir-618",
"hsa-mir-708",
"hsa-mir-9",
"hsa-mir-93")

# %%
EnhancedVolcano(miR_res_df, x="log2FoldChange", y="padj", lab = miR_res_df$miRNA_id, pCutoff = 0.05, FCcutoff = 2, selectLab = selectedGene)
# Out:
# plot without title

# %% [markdown]
# # RNA Differential Expression

# %%
query <- GDCquery(project = "TCGA-PRAD", 
                  data.category = "Gene expression",
                  data.type = "Gene expression quantification",
                  experimental.strategy = "RNA-Seq",
                  platform = "Illumina HiSeq",
                  file.type = "results",
                  legacy = TRUE)
# Out:
# --------------------------------------
#
# o GDCquery: Searching in GDC database
#
# --------------------------------------
#
# Genome of reference: hg19
#
# --------------------------------------------
#
# oo Accessing GDC. This might take a while...
#
# --------------------------------------------
#
# ooo Project: TCGA-PRAD
#
# --------------------
#
# oo Filtering results
#
# --------------------
#
# ooo By platform
#
# ooo By experimental.strategy
#
# ooo By data.type
#
# ooo By file.type
#
# ----------------
#
# oo Checking data
#
# ----------------
#
# ooo Checking if there are duplicated cases
#
# ooo Checking if there are results for the query
#
# -------------------
#
# o Preparing output
#
# -------------------

# %%
GDCdownload(query, method = "api", files.per.chunk = 100,
            directory = "/Desktop/Data")
# Out:
# Downloading data for project TCGA-PRAD
#
# GDCdownload will download 550 files. A total of 834.121914 MB
#
# Downloading chunk 1 of 6 (100 files, size = 151.869266 MB) as Tue_Jul__5_08_59_30_2022_0.tar.gz
# Downloading: 61 MB
# Downloading chunk 2 of 6 (100 files, size = 151.619367 MB) as Tue_Jul__5_08_59_30_2022_1.tar.gz
# Downloading: 61 MB
# Downloading chunk 3 of 6 (100 files, size = 151.62918 MB) as Tue_Jul__5_08_59_30_2022_2.tar.gz
# Downloading: 61 MB
# Downloading chunk 4 of 6 (100 files, size = 151.582944 MB) as Tue_Jul__5_08_59_30_2022_3.tar.gz
# Downloading: 61 MB
# Downloading chunk 5 of 6 (100 files, size = 151.708686 MB) as Tue_Jul__5_08_59_30_2022_4.tar.gz
# Downloading: 61 MB
# Downloading chunk 6 of 6 (50 files, size = 75.712471 MB) as Tue_Jul__5_08_59_30_2022_5.tar.gz
# Downloading: 30 MB

# %%
mrna_df <- GDCprepare(query, directory = "/Desktop/Data")
# Out:
# --------------------
#
# oo Reading 550 files
#
# --------------------
# |====================================================|100%                      Completed after 16 s
# --------------------
#
# oo Merging 550 files
#
# --------------------
#
# Starting to add information to samples
#
#  => Add clinical information to samples
#
#  => Adding TCGA molecular information from marker papers
#
#  => Information will have prefix 'paper_'
#
# prad subtype information from:doi:10.1016/j.cell.2015.10.025
#
# Available assays in SummarizedExperiment :
#   => raw_count
#   => scaled_estimate

# %%
mrna_meta <- mrna_df$sample

# %%
mrna_meta <- cbind(mrna_meta, mrna_df$definition)

# %%
mrna_df <- assay(mrna_df)

# %%
delim_fn = function(x, n, i){
    do.call(c, lapply(x, function(X)
        paste(unlist(strsplit(X, "-"))[(n+1):(i)], collapse = "-")))
}

# %%
colnames(mrna_df) <- delim_fn(x = colnames(mrna_df), n = 0, i = 4)

# %%
mrna_meta <- as.data.frame(mrna_meta)
mrna_df <- as.data.frame(mrna_df)

# %%
metastatic_key <- mrna_meta[which(mrna_meta[,2] == "Metastatic"),]
mrna_meta <- mrna_meta[!mrna_meta[,2] == metastatic_key[,2],]
mrna_df <- mrna_df[, -grep(paste0(metastatic_key[,1]), colnames(mrna_df))]

# %%
mrna_meta[,2] <- as.character(mrna_meta[,2])

# %%
mrna_meta[,2] <- gsub("Primary solid Tumor", "Tumor", mrna_meta[,2])
mrna_meta[,2] <- gsub("Solid Tissue Normal", "Normal", mrna_meta[,2])
mrna_meta[,2] <- as.factor(mrna_meta[,2])
levels(mrna_meta[,2])
colnames(mrna_meta) <- c("cases", "Condition")
# Out:
# [1] "Normal" "Tumor"

# %%
write.table(mrna_df, "/Desktop/mrna_df.txt", quote = F, sep = "\t")

# %%
write.table(mrna_meta, "/Desktop/mrna_meta.txt", quote = F, sep = "\t")

# %%
mrna_dds <- DESeqDataSetFromMatrix(round(mrna_df), colData = mrna_meta, design = ~ Condition)
# Out:
# converting counts to integer mode

# %%
mrna_dds$Condition <- relevel(mrna_dds$Condition, ref = "Normal")

# %%
mrna_dds <- DESeq(mrna_dds)
# Out:
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing
#
# -- replacing outliers and refitting for 1439 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
#
# estimating dispersions
#
# fitting model and testing

# %%
vsd <- varianceStabilizingTransformation(mrna_dds, blind=FALSE)

# %%
head(assay(vsd))
hist(assay(vsd))
# Out:
#             TCGA-G9-7525-01A TCGA-EJ-7789-01A TCGA-EJ-7314-11A TCGA-HC-8265-01A
# A1BG|1       6.008894         7.355672         7.672604         7.907780
# A2M|2       14.977996        14.768960        16.052200        14.783020
# NAT1|9       7.369287         5.967220         8.657079         8.214435
# NAT2|10      5.153428         4.052769         5.213812         4.687886
# SERPINA3|12 16.425500         8.755545        14.887241        16.042970
# AADAC|13     4.408430         4.052769         4.558712         4.052769
#             TCGA-EJ-A46B-01A TCGA-HC-7819-01A TCGA-EJ-5510-01A TCGA-HC-7080-01A
# A1BG|1       7.380921         6.189704         6.560988         5.889730
# A2M|2       13.568532        13.518895        14.263595        14.022247
# NAT1|9       9.172845         5.967724         8.689489         6.183797
# NAT2|10      5.166692         4.522975         5.095599         5.115032
# SERPINA3|12 10.837725        14.793632        15.035991        12.389362
# AADAC|13     4.052769         4.052769         4.359825         4.052769
#             TCGA-CH-5769-11A TCGA-KK-A7AY-01A ⋯ TCGA-G9-6377-01A
# A1BG|1       6.145200         6.520872        ⋯  6.584258
# A2M|2       14.657321        14.457274        ⋯ 13.784273
# NAT1|9       8.645634         5.524921        ⋯  8.042378
# NAT2|10      5.176564         4.514181        ⋯  4.859166
# SERPINA3|12 15.395851        12.833889        ⋯ 15.029958
# AADAC|13     4.521184         4.052769        ⋯  4.052769
#             TCGA-V1-A8MF-01A TCGA-G9-6499-11A TCGA-J4-A67R-01A TCGA-KK-A6E7-01A
# A1BG|1       6.959848         6.889952         7.406567         6.830122
# A2M|2       14.996586        15.086310        14.495920        14.170037
# NAT1|9       8.220037         9.312656         7.235903         9.267809
# NAT2|10      5.722875         5.025388         5.173697         6.807294
# SERPINA3|12 10.727668        14.168768        16.990727        10.022932
# AADAC|13     4.052769         4.052769         4.591437         4.518895
#             TCGA-J9-A8CN-01A TCGA-CH-5762-01A TCGA-XJ-A9DX-01A TCGA-KK-A6E5-01A
# A1BG|1       6.074995         5.411722         8.238785         7.448119
# A2M|2       14.425412        15.190929        13.686582        14.506364
# NAT1|9       9.088459         7.819305         5.980150         9.675646
# NAT2|10      4.465588         4.052769         4.052769         4.774214
# SERPINA3|12 14.148247        13.947195        10.260316        12.506878
# AADAC|13     4.052769         4.052769         4.052769         4.416300
#             TCGA-EJ-5496-01A
# A1BG|1       5.840184
# A2M|2       13.316533
# NAT1|9       7.288150
# NAT2|10      4.706704
# SERPINA3|12 14.000804
# AADAC|13     4.052769
# Plot with title “Histogram of assay(vsd)”

# %%
resultsNames(mrna_dds)
# Out:
# [1] "Intercept"                 "Condition_Tumor_vs_Normal"

# %%
# Plot Dispersions:
plotDispEsts(mrna_dds, main="Dispersion plot")
dev.off()
# Out:
# null device
#           1
# Plot with title “Dispersion plot”

# %%
mrna_res <- results(mrna_dds, name = "Condition_Tumor_vs_Normal")

# %%
plotMA(mrna_res)
# Out:
# Plot with title “”

# %%
mrna_res_df <- as.data.frame(mrna_res)

# %%
mrnaTable <- mrna_res_df

# %%
mrnaTable$Gene_id <- rownames(mrnaTable)

# %%
write.table(mrnaTable, "/Desktop/mrna_res_df.txt", quote = F, sep = "\t")

# %%
summary(mrna_res)
# Out:
# out of 19669 with nonzero total read count
# adjusted p-value < 0.1
# LFC > 0 (up)       : 6878, 35%
# LFC < 0 (down)     : 6338, 32%
# outliers [1]       : 0, 0%
# low counts [2]     : 0, 0%
# (mean count < 0)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results

# %%
mrna_upreg <- get_upregulated(mrna_res)

# %%
mrna_downreg <- get_downregulated(mrna_res)

# %%
mrna_counts <- counts(mrna_dds, normalized = T)

# %%
mrna_upreg$Gene_id <- rownames(mrna_upreg)

# %%
mrna_downreg$Gene_id <- rownames(mrna_downreg)

# %%
mrna_res_df$Gene_id <- rownames(mrna_res_df)

# %%
write.table(mrna_counts, "/Desktop/mRNA_norm.counts.txt", quote = F, sep = "\t")

# %%
write.table(mrna_res_df, "/Desktop/mrna_res_deseq2.txt", quote = F, sep = "\t")

# %%
write.table(mrna_upreg, "/Desktop/mRNA_upreg.txt", quote = F, sep = "\t", row.names = F)
write.table(mrna_downreg, "/Desktop/mRNA_downreg.txt", quote = F, sep = "\t", row.names = F)

# %%
write.csv(as.data.frame(mrna_upreg), file="mrna_upreg.csv")
write.csv(as.data.frame(mrna_downreg), file="mrna_downreg.csv")
write.csv(as.data.frame(mrna_counts), file="mrna_counts.csv")
write.csv(as.data.frame(mrna_res_df), file="mrna_res_df.csv")

# %%
head(mrna_res_df)
# Out:
#             baseMean     log2FoldChange lfcSE     stat       pvalue
# A1BG|1      1.484093e+02 -0.9550714     0.1764928 -5.4113893 6.253763e-08
# A2M|2       3.120417e+04 -0.2888566     0.1425595 -2.0262174 4.274251e-02
# NAT1|9      3.910508e+02 -0.1351429     0.2142276 -0.6308379 5.281465e-01
# NAT2|10     6.621447e+00 -1.0512134     0.2099215 -5.0076498 5.509867e-07
# SERPINA3|12 2.826762e+04  0.9478418     0.2722964  3.4809188 4.996969e-04
# AADAC|13    7.314742e-01  0.8801506     0.6443081  1.3660399 1.719264e-01
#             padj         Gene_id
# A1BG|1      2.311695e-07 A1BG|1
# A2M|2       6.609816e-02 A2M|2
# NAT1|9      6.202600e-01 NAT1|9
# NAT2|10     1.790411e-06 NAT2|10
# SERPINA3|12 1.065540e-03 SERPINA3|12
# AADAC|13    2.331027e-01 AADAC|13

# %%
EnhancedVolcano(mrna_res_df, x="log2FoldChange", y="padj", lab = mrna_res_df$Gene_id)
# Out:
# plot without title

# %%
EnhancedVolcano(mrna_res_df, x="log2FoldChange", y="padj", pCutoff = 0.05, FCcutoff = 2, lab = mrna_res_df$Gene_id)
# Out:
# plot without title

# %%
with(mrna_res_df, plot(log2FoldChange, -log10(padj), pch=20, main="Volcano plot", cex=1.0, xlab=bquote(~Log[2]~fold~change), ylab=bquote(~-log[10]~P~value)))

with(subset(mrna_res_df, padj<0.05 & abs(log2FoldChange)>2), points(log2FoldChange, -log10(padj), pch=20, col="red", cex=0.5))

#with(subset(mrna_res_df, padj<0.05 & abs(log2FoldChange)>2), text(log2FoldChange, -log10(padj), labels=subset(rownames(mrna_res_df), mrna_res_df$padj<0.05 & abs(mrna_res_df$log2FoldChange)>2), cex=0.8, pos=3))

#Add lines for absolute FC>2 and P-value cut-off at FDR Q<0.05
abline(v=0, col="black", lty=3, lwd=1.0)
abline(v=-2, col="black", lty=4, lwd=2.0)
abline(v=2, col="black", lty=4, lwd=2.0)
abline(h=-log10(max(mrna_res_df$pvalue[mrna_res_df$padj<0.05], na.rm=TRUE)), col="black", lty=4, lwd=2.0)
# Out:
# Plot with title “Volcano plot”

# %% [markdown]
# # DNA Methyalation
